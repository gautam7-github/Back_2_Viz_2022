# %%
import pandas as pd

# %%
df = pd.read_csv("https://query.data.world/s/ilk6fth2ppkbvedlsivc2rrvzqiboy")
df.to_excel("week4.xlsx",index=False)

# %%
df.head(5)
# Out:
#          Order ID  Order Date Region    Segment         Category Sub-Category  \
# 0  CA-2020-152156   11/8/2020  South   Consumer        Furniture    Bookcases
# 1  CA-2020-152156   11/8/2020  South   Consumer        Furniture       Chairs
# 2  CA-2020-138688   6/12/2020   West  Corporate  Office Supplies       Labels
# 3  US-2019-108966  10/11/2019  South   Consumer        Furniture       Tables
# 4  US-2019-108966  10/11/2019  South   Consumer  Office Supplies      Storage
#
#                                         Product Name   Ship Date  \
# 0                  Bush Somerset Collection Bookcase  11/11/2020
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  11/11/2020
# 2  Self-Adhesive Address Labels for Typewriters b...   6/16/2020
# 3      Bretford CR4500 Series Slim Rectangular Table  10/18/2019
# 4                     Eldon Fold 'N Roll Cart System  10/18/2019
#
#         Ship Mode    Profit  Quantity     Sales
# 0    Second Class   41.9136         2  261.9600
# 1    Second Class  219.5820         3  731.9400
# 2    Second Class    6.8714         2   14.6200
# 3  Standard Class -383.0310         5  957.5775
# 4  Standard Class    2.5164         2   22.3680

# %%
df.groupby(["Segment","Region"])["Profit","Sales"].sum()
# Out:
# <ipython-input-34-9681eb33e745>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["Segment","Region"])["Profit","Sales"].sum()
#                          Profit        Sales
# Segment     Region
# Consumer    Central   8564.0481  252031.4340
#             East     41190.9843  350908.1670
#             South    26913.5728  195580.9710
#             West     57450.6040  362880.7730
# Corporate   Central  18703.9020  157995.8128
#             East     23622.5789  200409.3470
#             South    15215.2232  121885.9325
#             West     34437.4299  225855.2745
# Home Office Central  12438.4124   91212.6440
#             East     26709.2168  127463.7260
#             South     4620.6343   74255.0015
#             West     16530.4150  136721.7770

# %%
dff = df.groupby("Product Name",as_index=False)[["Profit","Sales"]].agg(["sum","mean","max","min"])
